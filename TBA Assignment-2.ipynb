# %% [markdown]
# # CS-651-A TEXT BASED ANALYSIS
# # Sai Vandana - 0939231
# # Assignment - 2 4/13/2024¶

# %% [markdown]
# # Read the csv file
# The code reads the ecommerceDataset.csv dataset and prints the values from the dataset

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\tsaiv\OneDrive\documents\ecommerceDataset.csv")
df.head(20)
# Out:
#     Household  \
# 0   Household
# 1   Household
# 2   Household
# 3   Household
# 4   Household
# 5   Household
# 6   Household
# 7   Household
# 8   Household
# 9   Household
# 10  Household
# 11  Household
# 12  Household
# 13  Household
# 14  Household
# 15  Household
# 16  Household
# 17  Household
# 18  Household
# 19  Household
#
# ...

# %% [markdown]
# ##### To print the column names from the dataset

# %%
df.columns
# Out:
# Index(['Household', 'Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and
# ...

# %% [markdown]
# ##### To print the datatypes of each column

# %%
df.dtypes
# Out:
# Household                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
# ...

# %% [markdown]
# ##### To print the information about dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50424 entries, 0 to 50423
# Data columns (total 2 columns):
# ...

# %% [markdown]
# The describe() function is used to generate descriptive statistics that summarize the central tendency, dispersion, and shape of a dataset’s distribution.

# %%
df.describe()
# Out:
#         Household  \
# count       50424
# unique          4
# top     Household
# freq        19312
#
# ...

# %%
df.describe(include='O')
# Out:
#         Household  \
# count       50424
# unique          4
# top     Household
# freq        19312
#
# ...

# %% [markdown]
# ##### To add a new column length that will count the characters in the text column

# %%
df['length'] = df['Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some for eternal bliss.so bring home this elegant print that is lushed with rich colors that makes it nothing but sheer elegance to be to your friends and family.it would be treasured forever by whoever your lucky recipient is. Liven up your place with these intriguing paintings that are high definition hd graphic digital prints for home, office or any room.'].str.len()
df.describe()
# Out:
#              length
# count  50423.000000
# mean     714.099974
# std      973.380236
# min        4.000000
# 25%      219.000000
# 50%      487.000000
# 75%      954.000000
# max    50403.000000

# %% [markdown]
# To count the missing values in the dataset

# %%
df.isna().sum()
# Out:
# Household                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
# ...

# %% [markdown]
# ##### To replace the missing value with 'unknown' keyword

# %%
df['Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some for eternal bliss.so bring home this elegant print that is lushed with rich colors that makes it nothing but sheer elegance to be to your friends and family.it would be treasured forever by whoever your lucky recipient is. Liven up your place with these intriguing paintings that are high definition hd graphic digital prints for home, office or any room.'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# Household                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             
# ...

# %% [markdown]
# To convert text to uppercase

# %%
df['Household']= df['Household'].str.upper()
df['Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some for eternal bliss.so bring home this elegant print that is lushed with rich colors that makes it nothing but sheer elegance to be to your friends and family.it would be treasured forever by whoever your lucky recipient is. Liven up your place with these intriguing paintings that are high definition hd graphic digital prints for home, office or any room. '] = df['Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some for eternal bliss.so bring home this elegant print that is lushed with rich colors that makes it nothing but sheer elegance to be to your friends and family.it would be treasured forever by whoever your lucky recipient is. Liven up your place with these intriguing paintings that are high definition hd graphic digital prints for home, office or any room.'].str.upper()
df
# Out:
#          Household  \
# 0        HOUSEHOLD
# 1        HOUSEHOLD
# 2        HOUSEHOLD
# 3        HOUSEHOLD
# 4        HOUSEHOLD
# ...            ...
# 50419  ELECTRONICS
# 50420  ELECTRONICS
# 50421  ELECTRONICS
# 50422  ELECTRONICS
# 50423  ELECTRONICS
#
# ...

# %% [markdown]
# The Python code filters rows in a pandas DataFrame where the 'Household' column contains the string 'ELECTRONICS'.

# %%
df[df['Household'].str.contains('ELECTRONICS')]
# Out:
#          Household  \
# 39803  ELECTRONICS
# 39804  ELECTRONICS
# 39805  ELECTRONICS
# 39806  ELECTRONICS
# 39807  ELECTRONICS
# ...            ...
# 50419  ELECTRONICS
# 50420  ELECTRONICS
# 50421  ELECTRONICS
# 50422  ELECTRONICS
# 50423  ELECTRONICS
#
# ...

# %% [markdown]
# ##### To plot a line graph of a column named 'length' from a pandas DataFrame called 'df'.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is a pandas DataFrame with a column named 'length'

# For the line plot
df['length'].plot()
plt.show()

# %% [markdown]
# This code generates a horizontal box plot for the 'length' column of the DataFrame 'df' using pandas

# %%
# For the horizontal box plot
df['length'].plot(kind='box', vert=False)
plt.show()  # To display the plot

# %% [markdown]
# ##### The plotted histogram is used to represent the distribution of numerical data by dividing the data into bins or intervals and counting the number of observations in each bin.

# %%
df['length'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# This code creates a box plot for the 'length' column in a DataFrame 'df' where the 'Household' column contains either 'BOOKS' or 'CLOTHING & ACCESSORIES'.

# %%
import seaborn as sns
import pandas as pd
import warnings

# Corrected data filtering using query, which is more straightforward for this kind of operation
df_filtered = df.query("Household in ['BOOKS', 'CLOTHING & ACCESSORIES']")
warnings.filterwarnings('ignore', message='The figure layout has changed to tight')

# Plotting the boxplot using seaborn
g = sns.catplot(data=df_filtered, x="Household", y="length", kind='box')

# Set the figure size
g.fig.set_size_inches(8, 6)

# Use tight_layout to adjust plot parameters
g.fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# The provided function tokenize is a Python function that uses the regex module to find and return all the word-like substrings in the input text.

# %%
import regex as re

def tokenize(text):
    # This regular expression matches words and hyphenated words that contain at least one alphabet character
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# Example usage
text = """Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some for eternal bliss. So bring home this elegant print that is lushed with rich colors that makes it nothing but sheer elegance to be to your friends and family. It would be treasured forever by whoever your lucky recipient is. Liven up your place with these intriguing paintings that are high definition hd graphic digital prints for home, office or any room."""
tokens = tokenize(text)
print(tokens)
# Out:
# ['Paper', 'Plane', 'Design', 'Framed', 'Wall', 'Hanging', 'Motivational', 'Office', 'Decor', 'Art', 'Prints', 'X', 'inch', 'Set', 'of', 'Painting', 'made', 'up', 'in', 'synthetic', 'frame', 'with', 'uv', 'textured', 'print', 'which', 'gives', 'multi', 'effects', 'and', 'attracts', 'towards', 'it', 'This', 'is', 'an', 'special', 'series', 'of', 'paintings', 'which', 'makes', 'your', 'wall', 'very', 'beautiful', 'and', 'gives', 'a', 'royal', 'touch', 'This', 'painting', 'is', 'ready', 'to', 'hang', 'you', 'would', 'be', 'proud', 'to', 'possess', 'this', 'unique', 'painting', 'that', 'is', 'a', 'niche', 'apart', 'We', 'use', 'only', 'the', 'most', 'modern', 'and', 'efficient', 'printing', 'technology', 'on', 'our', 'prints', 'with', 'only', 'the', 'and', 'inks', 'and', 'precision', 'epson', 'roland', 'and', 'hp', 'printers', 'This', 'innovative', 'hd', 'printing', 'technique', 'results', 'in', 'durable', 'and', 'spectacular', 'looking', 'prints', 'of', 'the', 'highest', 'that', 'last', 
# ...

# %%
import re

def tokenize(text):
    return re.findall(r'[\w-]+', text)

testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
testtokens
# Out:
# ['Let',
#  's',
#  'defeat',
#  'SARS-CoV-2',
#  'together',
#  'in',
#  '2020',
#  'www',
#  'cdc',
#  'gov']

# %% [markdown]
# Sample text to perform tokenize function

# %%
testtext = "Let's defeat SARS-CoV-2 together in 2020! www.cdc.gov"
testtokens = tokenize(testtext)
 
print(testtokens)
# Out:
# ['Let', 's', 'defeat', 'SARS-CoV-2', 'together', 'in', '2020', 'www', 'cdc', 'gov']

# %% [markdown]
# The function remove_stop removes common English stopwords from a list of tokens.

# %%
# Assuming stopwords are typical English language stopwords, define them as follows:
stopwords = set([
    "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours",
    "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers",
    "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves",
    "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are",
    "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does",
    "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until",
    "while", "of", "at", "by", "for", "with", "about", "against", "between", "into",
    "through", "during", "before", "after", "above", "below", "to", "from", "up", "down",
    "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here",
    "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more",
    "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so",
    "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"
])

def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]

# Test the function
testtokens = ['This', 'is', 'a', 'test', 'of', 'the', 'function', 'with', 'stopwords']
cleantokens = remove_stop(testtokens)
print(cleantokens)
# Out:
# ['test', 'function', 'stopwords']

# %% [markdown]
# To perform stop words We will use the list of English stop words that are standard in python

# %%
from nltk.corpus import stopwords

# Existing stopwords
stop_words = set(stopwords.words('english'))

# Add a custom word to the stopword list
stop_words.add('sample')

# Remove a word from the stopword list
stop_words.discard('is')

print(stop_words)
# Out:
# {'if', "she's", 'that', 'be', 'more', 'few', 'we', 'are', 'ourselves', 'nor', 'any', 'against', 'aren', 'once', 'this', 'for', 't', 'over', 'these', 'hers', 'am', 'have', 'by', 'because', "you've", 'under', 'which', "you'll", 'my', 'being', 'ma', 'does', "needn't", 'both', 'them', 'up', 'each', 'only', "hadn't", 'off', 'm', 'until', 'whom', 'into', 'his', "wasn't", 'yours', 'himself', 'on', 'weren', "should've", 'or', "mustn't", 'he', 'y', 'been', 'most', 'doing', 'below', 'it', 'hadn', 'above', 'such', 'll', 'to', 'they', "isn't", "hasn't", 'further', 's', 'and', 'why', 'no', 'the', 'a', 'do', 'out', "aren't", "didn't", 'herself', 'of', 'same', 'through', 'did', 'how', "don't", 'don', 'yourselves', "that'll", 'while', 'i', 'where', 've', 'themselves', 'some', 'shouldn', 'ours', 'her', 'then', 'couldn', 'yourself', 'having', 'd', 'him', 'than', 'who', 'should', 'from', 'their', 'doesn', 'needn', 'those', 'so', 'itself', "wouldn't", 'she', 'mustn', 'were', 'at', 'sample', 'theirs', "s
# ...

# %% [markdown]
# ##### Function to create a pipeline

# %%
pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %% [markdown]
# ##### To print the created pipeline

# %%
df['tokens'] = df['Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some for eternal bliss.so bring home this elegant print that is lushed with rich colors that makes it nothing but sheer elegance to be to your friends and family.it would be treasured forever by whoever your lucky recipient is. Liven up your place with these intriguing paintings that are high definition hd graphic digital prints for home, office or any room.'].apply(prepare, pipeline=pipeline)

# %% [markdown]
# ##### using the counter method to count the words in a given string

# %%
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# ###### code to add new data to the current count

# %%
more_tokens = tokenize("She likes dogs and cats.")
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %% [markdown]
# ##### To count the most common elements

# %%
counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(8))
# Out:
# [('-', 24419), ('1', 20167), ('2', 16097), ('3', 13411), ('size', 13003), ('book', 12652), ('x', 12246), ('use', 12153)]

# %% [markdown]
# ###### To keep the word frequency in it’s own dataframe for analysis

# %%
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#         freq
# token
# -      24419
# 1      20167
# 2      16097
# 3      13411
# size   13003
# book   12652
# x      12246
# use    12153
# set    12114
# 5      11689

# %% [markdown]
# ##### To describe the data

# %%
freq_df.describe()
# Out:
#                freq
# count  93180.000000
# mean      42.430221
# std      307.795705
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%       10.000000
# max    24419.000000

# %% [markdown]
# ##### To display the bar chart between frequency and token

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %% [markdown]
# ##### To print the word cloud

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
import pandas as pd

# Correct column name as it appears in the DataFrame
column_name = "Paper Plane Design Framed Wall Hanging Motivational Office Decor Art Prints (8.7 X 8.7 inch) - Set of 4 Painting made up in synthetic frame with uv textured print which gives multi effects and attracts towards it. This is an special series of paintings which makes your wall very beautiful and gives a royal touch. This painting is ready to hang, you would be proud to possess this unique painting that is a niche apart. We use only the most modern and efficient printing technology on our prints, with only the and inks and precision epson, roland and hp printers. This innovative hd printing technique results in durable and spectacular looking prints of the highest that last a lifetime. We print solely with top-notch 100% inks, to achieve brilliant and true colours. Due to their high level of uv resistance, our prints retain their beautiful colours for many years. Add colour and style to your living space with this digitally printed painting. Some are for pleasure and some for eternal bliss.so bring home this elegant print that is lushed with rich colors that makes it nothing but sheer elegance to be to your friends and family.it would be treasured forever by whoever your lucky recipient is. Liven up your place with these intriguing paintings that are high definition hd graphic digital prints for home, office or any room."

# Filter the DataFrame
books_df = df.query("Household == 'BOOKS'")

# Access the complex column name safely, if it exists
if column_name in books_df.columns:
    text = books_df[column_name].values[0]
else:
    raise ValueError(f"Column not found: {column_name}")

# Create the WordCloud object, assuming 'stopwords' is defined
wc = WordCloud(max_words=100, stopwords=stopwords)

# Generate and display the word cloud
wc.generate(text)

# Display the plot
plt.figure(figsize=(14, 7))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ##### Another example for word cloud

# %%
wc = WordCloud(background_color='white', width = 300, height=300, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (6, 6), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
